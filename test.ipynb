# %%
from preprocessing_functions import read_files
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from preprocessing_functions import read_files
#
# ImportError: cannot import name 'read_files' from 'preprocessing_functions' (/Users/Afridorian/Library/CloudStorage/GoogleDrive-monroygi@usc.edu/My Drive/Spring 2026/DSCI 510/dsci510_spring2026_final_project/preprocessing_functions.py)

# %%
read_files('/Users/Afridorian/Library/CloudStorage/GoogleDrive-monroygi@usc.edu/My Drive/Spring 2026/DSCI 510/dsci510_spring2026_final_project/raw_data/WNBA_box_stats/player_box_2014.csv')
# Out:
#      game_id  season  season_type   game_date        game_date_time  \
# 0  400582775    2014            3  2014-09-12  2014-09-13T00:00:00Z
# 1  400582775    2014            3  2014-09-12  2014-09-13T00:00:00Z
# 2  400582775    2014            3  2014-09-12  2014-09-13T00:00:00Z
# 3  400582775    2014            3  2014-09-12  2014-09-13T00:00:00Z
# 4  400582775    2014            3  2014-09-12  2014-09-13T00:00:00Z
#
#    athlete_id athlete_display_name  team_id team_name team_location  ...  \
# 0         388         Penny Taylor       11   Mercury       Phoenix  ...
# 1         689       Candice Dupree       11   Mercury       Phoenix  ...
# 2         869       DeWanna Bonner       11   Mercury       Phoenix  ...
# 3         935       Ewelina Kobryn       11   Mercury       Phoenix  ...
# 4         585        Diana Taurasi       11   Mercury       Phoenix  ...
#
#   team_score  opponent_team_id  opponent_team_name  opponent_team_location  \
# ...
